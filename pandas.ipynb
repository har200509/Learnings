# %%
import pandas as pd

# %%
# creating a dataframe

dict={"M":[45,43,42],"P":[34,41,37],"C":[21,25,32],"E":[49,47,48],"CS":[35,38,47]}

df=pd.DataFrame(dict,index=["stu_1","stu_2","stu_3"])

df
# Out:
#         M   P   C   E  CS
# stu_1  45  34  21  49  35
# stu_2  43  41  25  47  38
# stu_3  42  37  32  48  47

# %%
# Basic attributes
# shape : (r,c)
t=df.shape

print(t)
# Out:
# (3, 5)

# %%
# First five entries
df.head()
# Out:
#         M   P   C   E  CS
# stu_1  45  34  21  49  35
# stu_2  43  41  25  47  38
# stu_3  42  37  32  48  47

# %%
S=pd.Series([1,2,3,4,5],index=[0,1,2,3,4],name="Numbers")
S
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Numbers, dtype: int64

# %%
# Reading a CSV FILE
DF=pd.read_csv('NYC_Jobs.csv',index_col=0)
DF.head()
# Out:
#                                Agency Posting Type  # Of Positions  \
# Job ID
# 424339  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 379094   NYC EMPLOYEES RETIREMENT SYS     External               1
# 520417          NYC HOUSING AUTHORITY     External               1
# 233549   NYC EMPLOYEES RETIREMENT SYS     External               1
# 510256        HUMAN RIGHTS COMMISSION     External               5
#
#                                        Business Title  \
# Job ID
# 424339  Triage Nurse, Bureau of Public Health Clinics
# 379094          CERTIFIED IT DEVELOPER (APPLICATIONS)
# 520417                            Chief of Settlement
# 233549  CERTIFIED IT ADMINISTRATOR (LAN/WAN), LEVEL 4
# 510256              Associate Human Rights Specialist
#
#                    Civil Service Title Title Classification Title Code No  \
# Job ID
# 424339             PUBLIC HEALTH NURSE        Competitive-1         51011
# ...

# %%
# Converting a df to CSV file
df_1 = pd.DataFrame({'Name': ['Alice', 'Bob'],'Age': [25, 30]})
df_1.to_csv('people.csv', index=False)
df_1=pd.read_csv("people.csv")
df_1
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
# Indexing [r,c] (indexing starts from 0)

# Index Based : iloc

C=df.iloc[:,2]
C
# Out:
# stu_1    21
# stu_2    25
# stu_3    32
# Name: C, dtype: int64

# %%
E=df.iloc[0:2,3]
E
# Out:
# stu_1    49
# stu_2    47
# Name: E, dtype: int64

# %%
P=df.iloc[[0,2],1]
P
# Out:
# stu_1    34
# stu_3    37
# Name: P, dtype: int64

# %%
# lablel based : loc

df.loc[:,["P","CS"]]
# Out:
#         P  CS
# stu_1  34  35
# stu_2  41  38
# stu_3  37  47

# %%
df.loc[['stu_1','stu_2'],['P','CS']]
# Out:
#         P  CS
# stu_1  34  35
# stu_2  41  38

# %%
# loc supports conditionals in () also
df.loc[(df.CS>45) & (df.E>40)]
# Out:
#         M   P   C   E  CS
# stu_3  42  37  32  48  47

# %%
# Some other attributes
df.describe()
# Out:
#                M          P          C     E         CS
# count   3.000000   3.000000   3.000000   3.0   3.000000
# mean   43.333333  37.333333  26.000000  48.0  40.000000
# std     1.527525   3.511885   5.567764   1.0   6.244998
# min    42.000000  34.000000  21.000000  47.0  35.000000
# 25%    42.500000  35.500000  23.000000  47.5  36.500000
# 50%    43.000000  37.000000  25.000000  48.0  38.000000
# 75%    44.000000  39.000000  28.500000  48.5  42.500000
# max    45.000000  41.000000  32.000000  49.0  47.000000

# %%
# return a array of unique entries in that column
df.M.unique()
# Out:
# array([45, 43, 42])

# %%
df.P.value_counts()
# Out:
# P
# 34    1
# 41    1
# 37    1
# Name: count, dtype: int64

# %%
# Mapping : applying a function on a row or a column
# is on a column(default) or a row(axis=column)

# apply :

DF.head()
# Out:
#                                Agency Posting Type  # Of Positions  \
# Job ID
# 424339  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 379094   NYC EMPLOYEES RETIREMENT SYS     External               1
# 520417          NYC HOUSING AUTHORITY     External               1
# 233549   NYC EMPLOYEES RETIREMENT SYS     External               1
# 510256        HUMAN RIGHTS COMMISSION     External               5
#
#                                        Business Title  \
# Job ID
# 424339  Triage Nurse, Bureau of Public Health Clinics
# 379094          CERTIFIED IT DEVELOPER (APPLICATIONS)
# 520417                            Chief of Settlement
# 233549  CERTIFIED IT ADMINISTRATOR (LAN/WAN), LEVEL 4
# 510256              Associate Human Rights Specialist
#
#                    Civil Service Title Title Classification Title Code No  \
# Job ID
# 424339             PUBLIC HEALTH NURSE        Competitive-1         51011
# ...

# %%
def func(title):
    return title.lower()

DF.Agency.apply(func)
# Out:
# Job ID
# 424339     dept of health/mental hygiene
# 379094      nyc employees retirement sys
# 520417             nyc housing authority
# 233549      nyc employees retirement sys
# 510256           human rights commission
#                        ...
# 457839      nyc employees retirement sys
# 527141    housing preservation & dvlpmnt
# 509443        financial info svcs agency
# 352367     dept of health/mental hygiene
# 478739           human rights commission
# Name: Agency, Length: 3773, dtype: object

# %%
# map: is for faster applying ie instant (pass dictionary)

DF["# Of Positions"].map({1:0})

# 1--> 0 and other-->NaN
# Out:
# Job ID
# 424339    0.0
# 379094    0.0
# 520417    0.0
# 233549    0.0
# 510256    NaN
#          ...
# 457839    0.0
# 527141    0.0
# 509443    0.0
# 352367    NaN
# 478739    0.0
# Name: # Of Positions, Length: 3773, dtype: float64

# %%
# star_ratings = reviews.apply(stars, axis='columns')

# %%
DF.head()

# original dataframe remains unchanges
# Out:
#                                Agency Posting Type  # Of Positions  \
# Job ID
# 424339  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 379094   NYC EMPLOYEES RETIREMENT SYS     External               1
# 520417          NYC HOUSING AUTHORITY     External               1
# 233549   NYC EMPLOYEES RETIREMENT SYS     External               1
# 510256        HUMAN RIGHTS COMMISSION     External               5
#
#                                        Business Title  \
# Job ID
# 424339  Triage Nurse, Bureau of Public Health Clinics
# 379094          CERTIFIED IT DEVELOPER (APPLICATIONS)
# 520417                            Chief of Settlement
# 233549  CERTIFIED IT ADMINISTRATOR (LAN/WAN), LEVEL 4
# 510256              Associate Human Rights Specialist
#
#                    Civil Service Title Title Classification Title Code No  \
# Job ID
# 424339             PUBLIC HEALTH NURSE        Competitive-1         51011
# ...

# %%
# Grouping : grouping similar entries by columns

g_p=DF.groupby('Posting Type')
g_p.describe()
# Out:
#              # Of Positions                                                  \
#                       count      mean        std  min  25%  50%  75%    max
# Posting Type
# External             1634.0  2.585067   9.313703  1.0  1.0  1.0  1.0  250.0
# Internal             2139.0  2.636746  10.126809  1.0  1.0  1.0  1.0  250.0
#
#              Salary Range From                ... Salary Range To            \
#                          count          mean  ...             75%       max
# Posting Type                                  ...
# External                1634.0  58028.280774  ...        110000.0  265000.0
# Internal                2139.0  57375.032642  ...        106381.0  265000.0
#
#              Recruitment Contact
#                            count mean std min 25% 50% 75% max
# Posting Type
# External                     0.0  NaN NaN NaN NaN NaN NaN NaN
# Internal                     0.0  NaN NaN NaN NaN NaN NaN NaN
#
# [2 rows x 32 columns]

# %%
g_p.agg({'# Of Positions':['min','max','count','mean']})
# Out:
#              # Of Positions
#                         min  max count      mean
# Posting Type
# External                  1  250  1634  2.585067
# Internal                  1  250  2139  2.636746

# %%
g_p_p=DF.groupby(['Posting Type','# Of Positions'])

# %%
g_p_p.describe()
# Out:
#                             Salary Range From                              \
#                                         count          mean           std
# Posting Type # Of Positions
# External     1                         1293.0  62291.966349  38671.026991
#              2                          147.0  46234.512135  31155.261431
#              3                           43.0  44632.801628  30806.640563
#              4                           21.0  36539.284986  28032.735575
#              5                           28.0  46030.652857  22249.432309
# ...                                       ...           ...           ...
# Internal     75                           4.0  18419.425000  36773.052179
#              80                           3.0     21.709133      4.401776
#              100                          1.0  30909.000000           NaN
#              101                          1.0     15.450000           NaN
# ...

# %%
# Sorting

DF.sort_values(by=['# Of Positions','Posting Type'],ascending=[False,False],inplace=True)

# inplace ensures changes are refelcted inoriginal dataframe

# %%
DF
# Out:
#                                Agency Posting Type  # Of Positions  \
# Job ID
# 513843     DEPT OF PARKS & RECREATION     Internal             250
# 513843     DEPT OF PARKS & RECREATION     Internal             250
# 513843     DEPT OF PARKS & RECREATION     External             250
# 457673          NYC HOUSING AUTHORITY     Internal             101
# 457673          NYC HOUSING AUTHORITY     External             101
# ...                               ...          ...             ...
# 526179     DEPT OF PARKS & RECREATION     External               1
# 528044      OFFICE OF THE COMPTROLLER     External               1
# 523965  OFFICE OF MANAGEMENT & BUDGET     External               1
# 524952      OFFICE OF THE COMPTROLLER     External               1
# 478739        HUMAN RIGHTS COMMISSION     External               1
#
#                                            Business Title  \
# Job ID
# 513843                  City Seasonal Aide/Security Guard
# ...

# %%
DF.nlargest(10,"# Of Positions")
# Out:
#                                 Agency Posting Type  # Of Positions  \
# Job ID
# 513843      DEPT OF PARKS & RECREATION     Internal             250
# 513843      DEPT OF PARKS & RECREATION     Internal             250
# 513843      DEPT OF PARKS & RECREATION     External             250
# 457673           NYC HOUSING AUTHORITY     Internal             101
# 457673           NYC HOUSING AUTHORITY     External             101
# 442559           NYC HOUSING AUTHORITY     Internal             100
# 442559           NYC HOUSING AUTHORITY     External             100
# 468629      DEPT OF PARKS & RECREATION     Internal              80
# 468629      DEPT OF PARKS & RECREATION     Internal              80
# 518491  DEPT OF ENVIRONMENT PROTECTION     Internal              80
#
#                            Business Title Civil Service Title  \
# Job ID
# 513843  City Seasonal Aide/Security Guard  CITY SEASONAL AIDE
# 513843  City Seasonal Aide/Security Guard  CITY SEASONAL AIDE
# ...

# %%
# Left :
# Data Types and Missing Values
# Renaming and Combining

# %%
# %pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
