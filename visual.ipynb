# %%
# Understading Data (7 questions)

import pandas as pd

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# How big data
t=df.shape
print(t)
# Out:
# (891, 12)

# %%
# How data looks
# 10 random row(records) better
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 649          650         1       3      Stanley, Miss. Amy Zillah Elsie
# 116          117         0       3                 Connors, Mr. Patrick
# 141          142         1       3             Nysten, Miss. Anna Sofia
# 264          265         0       3                   Henry, Miss. Delia
# 777          778         1       3        Emanuel, Miss. Virginia Ethel
# 380          381         1       1                Bidois, Miss. Rosalie
# 702          703         0       3                Barbara, Miss. Saiide
# 487          488         0       1              Kent, Mr. Edward Austin
# 130          131         0       3                 Drazenoic, Mr. Jozef
# 647          648         1       1  Simonius-Blumer, Col. Oberst Alfons
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 649  female  23.0      0      0  CA. 2314    7.5500   NaN        S
# ...

# %%
# Info about columns(attributes)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# duplicate rows(records)
t=df.duplicated().sum()
print(t)
# Out:
# 0

# %%
# data look mathematically (columns with int/float values)
# 75% - 75% of datapoints are less than (to the left) that value
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# pearson : linear correlation co-eff (-1 to 1)
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr(numeric_only=True)['Age']
# Out:
# PassengerId    0.036847
# Survived      -0.077221
# Pclass        -0.369226
# Age            1.000000
# SibSp         -0.308247
# Parch         -0.189119
# Fare           0.096067
# Name: Age, dtype: float64

# %%
# %pip install seaborn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# univariate analysis

# categorical data :
# --> category : count??
sns.countplot(x='Pclass', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: ylabel='count'>

# %%
# Numerical data:

# histogram : numerical to categorical data

plt.hist(x='Age',data=df,bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(x='Age',data=df,bins=15)

# more bins more peaks
# Out:
# (array([ 44.,  24.,  32., 104., 115., 127.,  80.,  59.,  49.,  30.,  22.,
#          17.,   4.,   6.,   1.]),
#  array([ 0.42      ,  5.72533333, 11.03066667, 16.336     , 21.64133333,
#         26.94666667, 32.252     , 37.55733333, 42.86266667, 48.168     ,
#         53.47333333, 58.77866667, 64.084     , 69.38933333, 74.69466667,
#         80.        ]),
#  <BarContainer object of 15 artists>)

# %%
# displot --> PDF
sns.displot(x='Age', data=df,kde=True, stat="probability")

# %%
df.Age.skew()
# Out:
# np.float64(0.38910778230082704)

# %%
tips = sns.load_dataset('tips')

# %%
titanic = pd.read_csv('train.csv')

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %%
# Bivariate analysis : analysis on two columns at the same time
## 1. Scatterplot (Numerical - Numerical)
sns.scatterplot(x='total_bill',y='tip',hue='sex',style='smoker',size='size',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Lineplot (numercial-numercial)
# use when you have a time based quantity (plot on x axis)
new_df=flights.groupby('year')['passengers'].sum().reset_index()
sns.lineplot(x='year',y='passengers',data=new_df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
## 2. Bar Plot (Numerical - Categorical)
# x-->category
# y-->numerical
# black rod--> 95% confidence interval for mean
sns.barplot(x='Pclass',y='Age',hue='Sex',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
## 3. Box Plot (Numerical - Categorical)
# x-->category
# y-->numerical
sns.boxplot(x='Sex',y='Age',hue='Survived',data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
## 4. Displot (Numerical - Categorical)
# filter --> categorical --> numerical
sns.kdeplot(titanic[titanic['Pclass'] == 1]['Age'].dropna(), label='Pclass 1')
sns.kdeplot(titanic[titanic['Pclass'] == 2]['Age'].dropna(), label='Pclass 2')
sns.kdeplot(titanic[titanic['Pclass'] == 3]['Age'].dropna(), label='Pclass 3')
plt.legend()

# %%
## 5. HeatMap (Categorical - Categorical)
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# %pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 6. ClusterMap (Categorical - Categorical)
# similar to heatmap but connects similar maps
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %%
# Multivariate
## 7. Pairplot (collection of scatterplots) [multiple numerical columns]
sns.pairplot(iris,hue='species')

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year',observed=False))
